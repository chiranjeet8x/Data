# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "Name" : ["Vivek","Rohit","Ram","Shayam"],
    "Marks" : [88,44,37,90],
    "City" : ["Noida","Delhi","Pune","Goa"]
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  Marks   City
# 0   Vivek     88  Noida
# 1   Rohit     44  Delhi
# 2     Ram     37   Pune
# 3  Shayam     90    Goa

# %%
df.to_csv("FriendsFalse.csv",index=False)

# %%
df.head(2)
# Out:
#     Name  Marks   City
# 0  Vivek     88  Noida
# 1  Rohit     44  Delhi

# %%
df.tail(2)
# Out:
#      Name  Marks  City
# 2     Ram     37  Pune
# 3  Shayam     90   Goa

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   64.750000
# std    28.158776
# min    37.000000
# 25%    42.250000
# 50%    66.000000
# 75%    88.500000
# max    90.000000

# %%
Train = pd.read_csv("TrainData.csv")

# %%
Train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Train No.  11 non-null     int64
#  1   Speed      11 non-null     int64
#  2   City       11 non-null     object
# dtypes: int64(2), object(1)
# memory usage: 396.0+ bytes

# %%
Train
# Out:
#     Train No.  Speed       City
# 0       11223     87      Noida
# 1       23322    161      Delhi
# 2      100992    103       Pune
# 3       56733    115        Goa
# 4      334488    118      Delhi
# 5     3444442    125     Kanpur
# 6      322442    105  Govindpur
# 7        5535    163  Itnanagar
# 8     2424244     89     Jiapur
# 9      422244    163     Mumbai
# 10      24444    130      Bihar

# %%
Train["Speed"][4] = 700
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6796\3272910615.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   Train["Speed"][4] = 700
# C:\Users\hp\AppData\Local\Temp\ipykernel_6796\3272910615.py:1: SettingWithCopyWarning:
# ...

# %%
Train
# Out:
#     Train No.  Speed       City
# 0       11223     87      Noida
# 1       23322    161      Delhi
# 2      100992    103       Pune
# 3       56733    115        Goa
# 4      334488    700      Delhi
# 5     3444442    125     Kanpur
# 6      322442    105  Govindpur
# 7        5535    163  Itnanagar
# 8     2424244     89     Jiapur
# 9      422244    163     Mumbai
# 10      24444    130      Bihar

# %%
Train.index = ["1st","2nd","3rd","4th","5th","6th","7th","8th","9th","10th","11TH"]

# %%
Train
# Out:
#       Train No.  Speed       City
# 1st       11223     87      Noida
# 2nd       23322    161      Delhi
# 3rd      100992    103       Pune
# 4th       56733    115        Goa
# 5th      334488    700      Delhi
# 6th     3444442    125     Kanpur
# 7th      322442    105  Govindpur
# 8th        5535    163  Itnanagar
# 9th     2424244     89     Jiapur
# 10th     422244    163     Mumbai
# 11TH      24444    130      Bihar

# %%
Train.to_csv("NewTrainData.csv")

# %%
# Series

# %%
ser = pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.273150
# 1     0.766915
# 2     0.446627
# 3     0.365233
# 4     0.219900
# 5     0.539244
# 6     0.772275
# 7     0.195769
# 8     0.524646
# 9     0.031621
# 10    0.046481
# 11    0.308785
# 12    0.948066
# 13    0.901124
# 14    0.771176
# 15    0.359174
# 16    0.448152
# 17    0.046230
# 18    0.990166
# 19    0.801409
# 20    0.668363
# 21    0.882985
# 22    0.140451
# 23    0.062031
# 24    0.742715
# 25    0.445118
# 26    0.120848
# 27    0.221888
# 28    0.981855
# 29    0.453615
# 30    0.230674
# 31    0.972067
# 32    0.633009
# 33    0.495180
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
# Data Frame

# %%
newdf = pd.DataFrame(np.random.rand(300,5),index = np.arange(300))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.253575  0.088179  0.043258  0.920920  0.216114
# 1  0.067465  0.529750  0.651308  0.856865  0.946747
# 2  0.907573  0.385482  0.230412  0.614719  0.207753
# 3  0.562845  0.245520  0.120643  0.416474  0.796237
# 4  0.126689  0.869934  0.808808  0.641918  0.802823

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  300.000000  300.000000  300.000000  300.000000  300.000000
# mean     0
# ..        ...       ...       ...       ...       ...
# 4    0.126689  0.869934  0.808808  0.641918  0.802823
# 3    0.562845  0.245520  0.120643  0.416474  0.796237
# 2    0.220000  0.385482  0.230412  0.614719  0.207753
# 1    0.067465  0.529750  0.651308  0.856865  0.946747
# 0    0.253575  0.088179  0.043258  0.920920  0.216114
#
# [300 rows x 5 columns]

# %%
newdf.loc[0,0] = 999

# %%
newdf.head(2)
# Out:
#             0         1         2         3         4
# 0  999.000000  0.088179  0.043258  0.920920  0.216114
# 1    0.067465  0.529750  0.651308  0.856865  0.946747

# %%
newdf.columns = list("ABCDE")
newdf.head(2)
# Out:
#             A         B         C         D         E
# 0  999.000000  0.088179  0.043258  0.920920  0.216114
# 1    0.067465  0.529750  0.651308  0.856865  0.946747

# %%
newdf.loc[0,"A"] = 88888
newdf.head(2)
# Out:
#               A         B         C         D         E
# 0  88888.000000  0.088179  0.043258  0.920920  0.216114
# 1      0.067465  0.529750  0.651308  0.856865  0.946747

# %%
newdf.head()
# Out:
#               A         B         C         D         E
# 0  88888.000000  0.088179  0.043258  0.920920  0.216114
# 1      0.067465  0.529750  0.651308  0.856865  0.946747
# 2      0.220000  0.385482  0.230412  0.614719  0.207753
# 3      0.562845  0.245520  0.120643  0.416474  0.796237
# 4      0.126689  0.869934  0.808808  0.641918  0.802823

# %%
newdf.loc[3,"E"] = 0000

# %%
newdf.head()
# Out:
#               A         B         C         D         E
# 0  88888.000000  0.088179  0.043258  0.920920  0.216114
# 1      0.067465  0.529750  0.651308  0.856865  0.946747
# 2      0.220000  0.385482  0.230412  0.614719  0.207753
# 3      0.562845  0.245520  0.120643  0.416474  0.000000
# 4      0.126689  0.869934  0.808808  0.641918  0.802823

# %%
newdf.loc[[1,2],["C","D"]]
# Out:
#           C         D
# 1  0.651308  0.856865
# 2  0.230412  0.614719

# %%
newdf.loc[:,["C","D"]]
# Out:
#             C         D
# 0    0.043258  0.920920
# 1    0.651308  0.856865
# 2    0.230412  0.614719
# 3    0.120643  0.416474
# 4    0.808808  0.641918
# ..        ...       ...
# 295  0.451083  0.470880
# 296  0.385195  0.400764
# 297  0.988886  0.785038
# 298  0.213499  0.428046
# 299  0.125376  0.920797
#
# [300 rows x 2 columns]

# %%
newdf.loc[[1,2],:]
# Out:
#           A         B         C         D         E
# 1  0.067465  0.529750  0.651308  0.856865  0.946747
# 2  0.220000  0.385482  0.230412  0.614719  0.207753

# %%
newdf.loc[(newdf["A"]<0.3)]
# Out:
#             A         B         C         D         E
# 1    0.067465  0.529750  0.651308  0.856865  0.946747
# 2    0.220000  0.385482  0.230412  0.614719  0.207753
# 4    0.126689  0.869934  0.808808  0.641918  0.802823
# 6    0.220737  0.298719  0.933283  0.670385  0.656233
# 9    0.110366  0.124160  0.328782  0.567193  0.464190
# ..        ...       ...       ...       ...       ...
# 288  0.272034  0.552327  0.871991  0.817457  0.389220
# 290  0.038721  0.255651  0.033394  0.790366  0.226473
# 292  0.009596  0.718074  0.169487  0.121548  0.784763
# 293  0.155156  0.318216  0.559194  0.942127  0.417612
# 296  0.152279  0.614551  0.385195  0.400764  0.066844
#
# [94 rows x 5 columns]

# %%
newdf.head(2)
# Out:
#               A         B         C         D         E
# 0  88888.000000  0.088179  0.043258  0.920920  0.216114
# 1      0.067465  0.529750  0.651308  0.856865  0.946747

# %%
newdf.iloc[1,3]
# Out:
# 0.8568647849373098

# %%
newdf.iloc[[0,1],[1,2]]
# Out:
#           B         D
# 0  0.088179  0.920920
# 4  0.869934  0.641918

# %%
newdf.drop([0])
# Out:
#             A         B         C         D         E
# 1    0.067465  0.529750  0.651308  0.856865  0.946747
# 2    0.220000  0.385482  0.230412  0.614719  0.207753
# 3    0.562845  0.245520  0.120643  0.416474  0.000000
# 4    0.126689  0.869934  0.808808  0.641918  0.802823
# 5    0.764212  0.328084  0.321521  0.771943  0.920438
# ..        ...       ...       ...       ...       ...
# 295  0.892893  0.816487  0.451083  0.470880  0.042381
# 296  0.152279  0.614551  0.385195  0.400764  0.066844
# 297  0.901402  0.351125  0.988886  0.785038  0.784281
# 298  0.751590  0.193861  0.213499  0.428046  0.072918
# 299  0.786915  0.047135  0.125376  0.920797  0.873686
#
# [299 rows x 5 columns]

# %%
newdf.drop(["A","B"], axis=1)
# Out:
#             C         D         E
# 0    0.043258  0.920920  0.216114
# 1    0.651308  0.856865  0.946747
# 2    0.230412  0.614719  0.207753
# 3    0.120643  0.416474  0.000000
# 4    0.808808  0.641918  0.802823
# ..        ...       ...       ...
# 295  0.451083  0.470880  0.042381
# 296  0.385195  0.400764  0.066844
# 297  0.988886  0.785038  0.784281
# 298  0.213499  0.428046  0.072918
# 299  0.125376  0.920797  0.873686
#
# [300 rows x 3 columns]

# %%
newdf.head(4)
# Out:
#               A         B         C         D         E
# 0  88888.000000  0.088179  0.043258  0.920920  0.216114
# 1      0.067465  0.529750  0.651308  0.856865  0.946747
# 2      0.220000  0.385482  0.230412  0.614719  0.207753
# 3      0.562845  0.245520  0.120643  0.416474  0.000000

# %%
newdf.drop(["A","B"], axis = 1, inplace=True)

# %%
newdf.head(4)
# Out:
#           C         D         E
# 0  0.043258  0.920920  0.216114
# 1  0.651308  0.856865  0.946747
# 2  0.230412  0.614719  0.207753
# 3  0.120643  0.416474  0.000000

# %%
newdf.drop([1,2], axis = 0, inplace=True)
newdf.head(4)
# Out:
#           C         D         E
# 0  0.043258  0.920920  0.216114
# 3  0.120643  0.416474  0.000000
# 4  0.808808  0.641918  0.802823
# 5  0.321521  0.771943  0.920438

# %%
newdf.reset_index()
# Out:
#      index         C         D         E
# 0        0  0.043258  0.920920  0.216114
# 1        3  0.120643  0.416474  0.000000
# 2        4  0.808808  0.641918  0.802823
# 3        5  0.321521  0.771943  0.920438
# 4        6  0.933283  0.670385  0.656233
# ..     ...       ...       ...       ...
# 293    295  0.451083  0.470880  0.042381
# 294    296  0.385195  0.400764  0.066844
# 295    297  0.988886  0.785038  0.784281
# 296    298  0.213499  0.428046  0.072918
# 297    299  0.125376  0.920797  0.873686
#
# [298 rows x 4 columns]

# %%
newdf.head(5)
# Out:
#           C         D         E
# 0  0.043258  0.920920  0.216114
# 3  0.120643  0.416474  0.000000
# 4  0.808808  0.641918  0.802823
# 5  0.321521  0.771943  0.920438
# 6  0.933283  0.670385  0.656233

# %%
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head(5)
# Out:
#           C         D         E
# 0  0.043258  0.920920  0.216114
# 1  0.120643  0.416474  0.000000
# 2  0.808808  0.641918  0.802823
# 3  0.321521  0.771943  0.920438
# 4  0.933283  0.670385  0.656233

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    4 non-null      object
#  1   Marks   4 non-null      int64
#  2   City    4 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 228.0+ bytes
